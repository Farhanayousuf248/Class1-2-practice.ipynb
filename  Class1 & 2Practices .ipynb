# %%
print ("Hello Farhana")
# Out:
# Hello Farhana

# %%
print ("Farhana")
# Out:
# Farhana

# %%
#comment use 📌

# %% [markdown]
# 💡Variables👇use

# %%
#  Change tha name
myname="Farhana yousuf"
print(myname)
# Out:
# Farhana yousuf

# %%
fev_celebrity ="my parents"
print (fev_celebrity)
# Out:
# my parents

# %% [markdown]
# {I am using variable with data type.  "str","int","bool"}

# %%
# str:use in alphabets .etc
#int:use in numbers.etc
#bool: use  True or false
teachername :str="missAisha"
print (teachername)
# Out:
# missAisha

# %%
Marks:int="80"
print (Marks)
# Out:
# 80

# %%
allowed:bool="True"
print(allowed)
# Out:
# True

# %% [markdown]
# 💡Data type use in names

# %%
uname:str="Farhana"
uname="Farhana yousuf"
print (uname)
# Out:
# Farhana yousuf

# %%
name:str="Farhana"
print (name)
# Out:
# Farhana

# %%
age:int="18 years"
print (age)
# Out:
# 18 years

# %%
in_active:bool="True"
print (in_active)
# Out:
# True
